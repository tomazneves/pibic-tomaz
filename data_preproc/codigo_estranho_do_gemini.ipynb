# %%
import json
from collections import defaultdict

def visualizar_arvore_textual(no_raiz, arvore_invertida, prefixo="", eh_ultimo=True):
    """
    Função recursiva para imprimir a sub-árvore de um nó específico.

    Args:
        no_raiz (str): O nó a partir do qual a árvore será impressa.
        arvore_invertida (dict): Dicionário representando a árvore (pai -> lista de filhos).
        prefixo (str): O prefixo de formatação para as linhas (para os conectores).
        eh_ultimo (bool): Flag para saber se é o último nó no seu nível.
    """
    # Imprime o nó atual com a formatação de árvore
    print(prefixo + ("└── " if eh_ultimo else "├── ") + no_raiz)
    
    # Prepara o prefixo para os nós filhos
    prefixo += "    " if eh_ultimo else "│   "
    
    # Pega a lista de filhos do nó atual
    filhos = arvore_invertida.get(no_raiz, [])
    
    # Itera sobre os filhos e chama a função recursivamente
    for i, filho in enumerate(filhos):
        eh_ultimo_filho = (i == len(filhos) - 1)
        visualizar_arvore_textual(filho, arvore_invertida, prefixo, eh_ultimo_filho)

# --- Script Principal ---

# 1. Carregar os arquivos JSON
try:
    with open('arvore_do_conhecimento.json', 'r', encoding='utf-8') as f:
        knowledge_tree = json.load(f)
except FileNotFoundError:
    knowledge_tree = {}

try:
    with open('areas_fantasma.json', 'r', encoding='utf-8') as f:
        new_areas = json.load(f)
except FileNotFoundError:
    new_areas = {}

# 2. Mesclar as novas áreas na árvore principal
knowledge_tree.update(new_areas)

# 3. Inverter a árvore para um formato (pai -> lista de filhos)
arvore_adjacencia = defaultdict(list)
raizes = []
for filho, pai in knowledge_tree.items():
    if pai:
        arvore_adjacencia[pai].append(filho)
    else:
        # Se o pai é nulo, o nó é uma das raízes da floresta (Grande Área)
        raizes.append(filho)

# 4. Exemplo de uso: Visualizar uma das Grandes Áreas
# Você pode trocar 'engenharias' por qualquer outra Grande Área ou nó da árvore.
# Grandes Áreas disponíveis: ciencias agrarias, ciencias biologicas, ciencias da saude,
# ciencias exatas e da terra, engenharias, ciencias humanas, ciencias sociais aplicadas,
# linguistica; letras e artes.

print("Visualizando o ramo da Grande Área: 'engenharias'")
print("-" * 50)
visualizar_arvore_textual('engenharias', arvore_adjacencia)

print("\n" + "-" * 50)
print("Visualizando o ramo da Grande Área: 'ciencias da saude'")
print("-" * 50)
visualizar_arvore_textual('ciencias da saude', arvore_adjacencia)
# Out:
# Visualizando o ramo da Grande Área: 'engenharias'
# --------------------------------------------------
# └── engenharias
#     ├── engenharia civil
#     │   ├── construcao civil
#     │   │   ├── materiais e componentes de construcao
#     │   │   ├── processos construtivos
#     │   │   │   ├── praticas construtivas
#     │   │   │   └── canteiros experimentais
#     │   │   ├── instalacoes prediais
#     │   │   ├── manutencao predial
#     │   │   ├── incorporacao
#     │   │   ├── infraestrutura
#     │   │   ├── construcao enxuta
#     │   │   ├── consultoria em impermeabilizacao
#     │   │   ├── impermeabilizacao em edificacoes
#     │   │   ├── orcamento de obras
#     │   │   ├── ensaios de laboratorio
#     │   │   └── infraestrutura e energia
#     │   ├── estruturas
#     │   │   ├── estruturas de concreto
#     │   │   ├── estruturas de madeiras
#     │   │   ├── estruturas metalicas
#     │   │   │   ├── estruturas de aco e mistas
#     │   │   │   ├── estruturas de aco
#     │   │   │   └── estruturas metalicas e mistas
#     │   │   ├── mecanica das estruturas
#     │   │   ├── estabilidade e dinamica das estruturas
#     │   │   ├── dinamica das estruturas
#     │   │   ├── estruturas espaciais
#     │   │   ├── estruturas tombadas
#     │   │   ├── estruturas de bambu
#     │   │   ├── engenharia estrutural
#     │   │   ├── integridade estrutural
#     │   │   ├── interacao solo-estrutura
#     │   │   └── instabilidade e dinamica de estruturas
#     │   ├── geotecnica
#     │   │   ├── fundacoes e escavacoes
#     │   │   ├── mecanicas das rochas
#     │   │   │   └── mecanica das rochas
#     │   │   ├── mecanicas dos solos
#     │   │   │   ├── cisalhamento de areias
#     │   │   │   ├── comportamento de areias
#     │   │   │   ├── dinamica dos solos
#     │   │   │   ├── mecanica dos solos
#     │   │   │   └── solos nao saturados
#     │   │   ├── obras de terra e enrocamento
#     │   │   ├── pavimentos
#     │   │   ├── geotecnia ambiental
#     │   │   ├── novos materiais geotecnicos
#     │   │   ├── geotecnia computacional
#     │   │   ├── mecanica das rochas e geologia de engenharia
#     │   │   ├── geomecanica computacional
#     │   │   ├── geomecanica
#     │   │   ├── geotecnia experimental
#     │   │   ├── geomecanica experimental
#     │   │   └── geotechnical engineering
#     │   ├── engenharia hidraulica
#     │   │   ├── hidraulica
#     │   │   └── hidrologia
#     │   ├── infra-estrutura de transportes
#     │   │   ├── aeroportos; projeto e construcao
#     │   │   ├── ferrovias; projetos e construcao
#     │   │   ├── portos e vias nevegaveis; projeto e construcao
#     │   │   ├── rodovias; projeto e construcao
#     │   │   └── portos e vias navegaveis; projeto e construcao
#     │   ├── geotecnia
#     │   │   └── metodos numericos em geotecnia
#     │   ├── ingenharia civil
#     │   └── engenharia civil / estruturas.
#     ├── engenharia de minas
#     │   ├── pesquisa mineral
#     │   │   ├── caracterizacao do minerio
#     │   │   └── dimensionamento de jazidas
#     │   └── lavra
#     │       ├── lavra a ceu aberto
#     │       ├── lavra de mina subterranea
#     │       ├── equipamentos de lavra
#     │       ├── perfuracao
#     │       ├── perfuracao de poco de petroleo
#     │       ├── extracao de petroleo
#     │       ├── producao de petroleo
#     │       ├── recuperacao de petroleo
#     │       ├── estabilidade de poco
#     │       └── completacao de pocos
#     ├── engenharia de materiais e metalurgica
#     │   ├── instalacoes e equipamentos metalurgicos
#     │   │   ├── instalacoes metalurgicas
#     │   │   └── equipamentos metalurgicos
#     │   ├── metalurgia extrativa
#     │   │   ├── tratamento de minerios
#     │   │   │   ├── metodos de concentracao e enriquecimento de minerios
#     │   │   │   └── equipamentos de beneficiamento de minerios
#     │   │   ├── aglomeracao
#     │   │   ├── eletrometalurgia
#     │   │   ├── hidrometalurgia
#     │   │   └── pirometalurgia
#     │   ├── metalurgia de transformacao
#     │   │   ├── conformacao mecanica
#     │   │   ├── fundicao
#     │   │   ├── metalurgia de po
#     │   │   │   ├── po na industria
#     │   │   │   ├── po na area de saude
#     │   │   │   └── metalurgia do po
#     │   │   ├── recobrimentos
#     │   │   ├── soldagem
#     │   │   │   └── soldagem a laser
#     │   │   ├── tratamentos termicos; mecanicos e quimicos
#     │   │   ├── usinagem
#     │   │   ├── processamento de materiais - siderurgia
#     │   │   ├── processos siderurgicos
#     │   │   ├── revestimentos ultraduros
#     │   │   ├── coqueificacao / carbonizacao
#     │   │   ├── processo siderurgico
#     │   │   ├── revestimentos
#     │   │   ├── tratamento de superficies
#     │   │   └── tratamentos termicos, mecanicos e quimicos
#     │   ├── metalurgia fisica
#     │   │   ├── estrutura dos metais e ligas
#     │   │   ├── propriedades fisicas dos metais e ligas
#     │   │   ├── propriedades mecanicas dos metais e ligas
#     │   │   ├── transformacao de fases
#     │   │   │   └── transformaco de fases
#     │   │   ├── corrosao
#     │   │   │   └── biocorrosao
#     │   │   └── caracterizacao microestrutural
#     │   ├── materiais nao-metalicos
#     │   │   ├── extracao e transformacao de materiais
#     │   │   ├── ceramicos
#     │   │   ├── materiais conjugados nao-metalicos
#     │   │   ├── polimeros; aplicacoes
#     │   │   │   ├── polimeros, aplicacoes
#     │   │   │   └── caracterizacao eletrica, termica mecanica e otica de materiais polimericos
#     │   │   ├── materiais ceramicos com expansao termica negativa
#     │   │   ├── materiais nao convencionais
#     │   │   ├── materiais compositos
#     │   │   ├── materiais nao-convencionais
#     │   │   ├── compositos
#     │   │   └── materiais ceramicos
#     │   ├── novos materiais
#     │   ├── materials
#     │   ├── materiais metalicos e nao metalicos
#     │   ├── characterization
#     │   ├── natural fibers
#     │   ├── materiais funcionais
#     │   ├── engenharia metalurgica
#     │   ├── materiais nanoestruturados
#     │   ├── materiais avancados e nanotecnologias
#     │   ├── materiais avancados
#     │   ├── ciencia de materiais, design,
#     │   ├── ciencia dos materiais
#     │   ├── desenvolvimento de novos materiais
#     │   ├── nanomateriais
#     │   ├── materiais e tecnologias nao-convencionais
#     │   ├── materias
#     │   ├── caracterizacao
#     │   ├── micro e nanotecnologias
#     │   ├── caracterizacao de materiais
#     │   ├── nanomaterias
#     │   └── nanotecnologia
#     ├── engenharia eletrica
#     │   ├── materiais eletricos
#     │   │   ├── materiais condutores
#     │   │   ├── materiais e componentes semicondutores
#     │   │   ├── materiais e dispositivos supercondutores
#     │   │   │   ├── supercondutores ceramicos
#     │   │   │   └── materiais supercondutores ceramicos
#     │   │   ├── materiais dieletricos; piezoeletricos e ferroeletricos
#     │   │   │   └── materiais dieletricos, piezoeletricos e ferroeletricos
#     │   │   ├── materiais e componentes eletrooticos e magnetooticos; materiais fotoeletricos
#     │   │   ├── materiais e dispositivos magneticos
#     │   │   └── materiais e componentes eletrooticos e magnetooticos, materiais fotoeletricos
#     │   ├── medidas eletricas; magneticas e eletronicas; instrumentacao
#     │   │   ├── medidas eletricas
#     │   │   ├── medidas magneticas
#     │   │   ├── instrumentacao eletromecanica
#     │   │   ├── instrumentacao eletronica
#     │   │   │   ├── instrumentacao optoeletronica
#     │   │   │   └── sensores
#     │   │   ├── sistemas eletronicos de medida e de controle
#     │   │   └── medidas eletricas, magneticas e eletronicas; instrumentacao
#     │   ├── circuitos eletricos; magneticos e eletronicos
#     │   │   ├── teoria geral dos circuitos eletricos
#     │   │   ├── circuitos lineares e nao-lineares
#     │   │   ├── circuitos eletronicos
#     │   │   │   └── microeletronica
#     │   │   ├── circuitos magneticos; magnetismos e eletromagnetismos
#     │   │   ├── circuitos magneticos , magnetismos e eletromagnetismos
#     │   │   └── circuitos eletricos, magneticos e eletronicos
#     │   ├── sistemas eletricos de potencia
#     │   │   ├── geracao da energia eletricas
#     │   │   │   └── geracao da energia eletrica
#     │   │   ├── transmissao da energia eletrica; distribuicao da energia eletrica
#     │   │   │   └── transmissao da energia eletrica, distribuicao da energia eletrica
#     │   │   ├── conversao e retificacao da energia eletrica
#     │   │   ├── medicao; controle; correcao e protecao de sistemas eletricos de potencia
#     │   │   ├── maquinas eletricas e dispositivos de potencia
#     │   │   ├── instalacoes eletricas e industriais
#     │   │   ├── sistemas de energia eletrica
#     │   │   ├── unit commitment
#     │   │   ├── medicao, controle, correcao e protecao de sistemas eletricos  de potencia
#     │   │   ├── power system planning
#     │   │   ├── power systems operation
#     │   │   ├── confiabilidade de sistemas eletricos
#     │   │   ├── planejamento do sistema de transmissao
#     │   │   ├── fornecimento de energia eletrica
#     │   │   ├── monitoracao de sistemas de potencia
#     │   │   ├── planejamento e operacao de sistemas eletricos de potencia
#     │   │   ├── energia eletrica
#     │   │   ├── manutencao de sistemas eletricos
#     │   │   ├── sistemas de distribuicao
#     │   │   └── manutencao de equipamentos eletricos
#     │   ├── eletronica industrial; sistemas e controles eletronicos
#     │   │   ├── eletronica industrial
#     │   │   ├── automacao eletronica de processos eletricos e industriais
#     │   │   │   ├── eletronica e controle de processos
#     │   │   │   ├── engenharia de controle e robotica
#     │   │   │   ├── mecatronica
#     │   │   │   ├── robotica, mecatronica e automacao
#     │   │   │   ├── automacao
#     │   │   │   ├── elementos de atuacao e controle
#     │   │   │   ├── robotica inteligente
#     │   │   │   └── automacao e controle
#     │   │   ├── controle de processos eletronicos; retroalimentacao
#     │   │   │   ├── modelagem e identificacao de processos
#     │   │   │   └── controle de processos eletronicos, retroalimentacao
#     │   │   └── eletronica industrial, sistemas e controles eletronicos
#     │   └── telecomunicacoes
#     │       ├── teoria eletromagnetica; microondas; propagacao de ondas; antenas
#     │       ├── radionavegacao e radioastronomia
#     │       ├── sistemas de telecomunicacoes
#     │       │   └── sistemas de comunicacoes, processamento de sinais
#     │       ├── fibra otica
#     │       ├── processamento de video
#     │       ├── processamento de sinais
#     │       ├── transdutores de fibra otica
#     │       ├── comunicacoes opticas
#     │       ├── teoria eletromagnetica, microondas, propagacao de ondas, antenas
#     │       ├── redes e telecomunicacoes
#     │       ├── filtros digitais
#     │       ├── redes sem fio
#     │       └── sistemas de comunicacao sem fio
#     ├── engenharia mecanica
#     │   ├── fenomenos de transporte
#     │   │   ├── transferencia de calor
#     │   │   │   └── transferencia de calor com mudanca de fase
#     │   │   ├── mecanica dos fluidos
#     │   │   │   ├── mecanica dis fluidos
#     │   │   │   ├── fluid mechanics
#     │   │   │   └── non-newtonian fluids
#     │   │   ├── dinamica dos gases
#     │   │   ├── principios variacionais e metodos numericos
#     │   │   ├── microfluidica
#     │   │   ├── modelagem fisica de processos
#     │   │   └── modelagem matematica de processos
#     │   ├── engenharia termica
#     │   │   ├── termodinamica
#     │   │   ├── controle ambiental
#     │   │   ├── aproveitamento da energia
#     │   │   │   ├── sistemas hibridos e sistemas nao-convencionais de armazenagem de energia
#     │   │   │   ├── energia solar fotovoltaica
#     │   │   │   ├── sistemas energeticos
#     │   │   │   ├── energia solar termica
#     │   │   │   ├── sistema de energia
#     │   │   │   ├── uso eficiente de energia
#     │   │   │   ├── energia eolica
#     │   │   │   ├── energias renovaveis e ambiente
#     │   │   │   ├── planejamento energetico
#     │   │   │   ├── fontes renovaveis de energia
#     │   │   │   ├── engenharia de energia
#     │   │   │   ├── energia
#     │   │   │   ├── energia renovaveis
#     │   │   │   ├── analise de impactos produzidos por sistemas energeticos
#     │   │   │   ├── biocombustiveis
#     │   │   │   └── energia e infraestrutura
#     │   │   ├── termociencias
#     │   │   ├── combustao
#     │   │   ├── combustiveis e combustao industrial
#     │   │   ├── experimental methods in thermosciences
#     │   │   └── refrigeracao
#     │   ├── mecanica dos solidos
#     │   │   ├── mecanica dos corpos solidos; elasticos e plasticos
#     │   │   ├── dinamica dos corpos rigidos; elasticos e plasticos
#     │   │   │   └── dinamica dos corpos rigidos, elasticos e plasticos
#     │   │   ├── analise de tensoes
#     │   │   ├── termoelasticidade
#     │   │   ├── modelos constitutivos
#     │   │   ├── materiais granulares
#     │   │   ├── instabilidade
#     │   │   ├── sistemas granulares
#     │   │   ├── mecanica aplicada
#     │   │   ├── fluencia
#     │   │   ├── dinamica
#     │   │   ├── comportamento mecanico
#     │   │   ├── fratura de materiais estruturais
#     │   │   ├── mecanica dos corpos solidos, elasticos e plasticos
#     │   │   ├── mecanica da fratura
#     │   │   ├── acumulo de danos
#     │   │   ├── simulaciones numericas y mecanica computacional
#     │   │   ├── mecanica da fratura e fadiga
#     │   │   ├── analise dinamica nao linear
#     │   │   ├── fadiga de materiais estruturais
#     │   │   └── metodos experimentais em mecanica dos solidos
#     │   ├── projetos de maquinas
#     │   │   ├── teoria dos mecanismos
#     │   │   ├── estatica e dinamica aplicada
#     │   │   ├── elementos de maquinas
#     │   │   ├── fundamentos gerais de projetos das maquinas
#     │   │   ├── maquinas; motores e equipamentos
#     │   │   ├── metodos de sintese e otimizacao aplicados ao projeto mecanico
#     │   │   ├── controle de sistemas mecanicos
#     │   │   ├── aproveitamento de energia
#     │   │   ├── dinamica de veiculos
#     │   │   ├── projetos mecanicos
#     │   │   ├── maquinas, motores e equipamentos
#     │   │   └── otimizacao de projeto
#     │   ├── processos de fabricacao
#     │   │   ├── matrizes e ferramentas
#     │   │   ├── maquinas de usinagem e conformacao
#     │   │   ├── controle numerico
#     │   │   ├── robotizacao
#     │   │   ├── processos de fabricacao; selecao economica
#     │   │   ├── processos de fabricacao, selecao economica
#     │   │   ├── inspecao nao destrutiva
#     │   │   ├── oficina covencional
#     │   │   ├── cad/cam
#     │   │   ├── cad
#     │   │   ├── manufatura aditiva
#     │   │   ├── fabricacao digital
#     │   │   ├── prototipagem rapida
#     │   │   ├── ensaios nao destrutivos
#     │   │   ├── operacao e manutencao de impressoras tridimensionais
#     │   │   ├── manufatura avancada
#     │   │   ├── microfabrication
#     │   │   ├── prototipagem rapida e prototipagem convencional
#     │   │   ├── juncao de materiais
#     │   │   ├── computer-aided design
#     │   │   └── impressao 3d
#     │   ├── engenharia mecanica e de automoveis
#     │   ├── engenharia mecanica e de armamento
#     │   ├── engenharia automotiva
#     │   └── mechanical engineering
#     ├── engenharia quimica
#     │   ├── processos industriais de engenharia quimica
#     │   │   ├── processos bioquimicos
#     │   │   ├── processos organicos
#     │   │   └── processos inorganicos
#     │   ├── operacoes industriais e equipamentos para engenharia quimica
#     │   │   ├── reatores quimicos
#     │   │   ├── operacoes caracteristicas de processos bioquimicos
#     │   │   └── operacoes de separacao e mistura
#     │   │       ├── estudo do processo de formacao de membranas
#     │   │       ├── processos de separacao com membranas
#     │   │       ├── osmose inversa e nanofiltracao
#     │   │       └── operacoes de separacao e misturas
#     │   ├── tecnologia quimica
#     │   │   ├── ceramica
#     │   │   ├── balancos globais de materia e energia
#     │   │   ├── agua
#     │   │   ├── alcool
#     │   │   ├── alimentos
#     │   │   ├── borrachas
#     │   │   ├── carvao
#     │   │   │   └── quimica do carvao
#     │   │   ├── cimento
#     │   │   ├── couro
#     │   │   ├── detergentes
#     │   │   ├── fertilizantes
#     │   │   ├── medicamentos
#     │   │   ├── metais nao-ferrosos
#     │   │   │   ├── nao ferrosos
#     │   │   │   └── materiais nao-ferrosos
#     │   │   ├── oleos
#     │   │   ├── papel e celulose
#     │   │   ├── petroleo e petroquimica
#     │   │   │   └── petroleo
#     │   │   ├── polimeros
#     │   │   ├── produtos naturais
#     │   │   ├── texteis
#     │   │   │   └── tratamento de superficie textil
#     │   │   ├── tratamentos e aproveitamento de rejeitos
#     │   │   ├── xisto
#     │   │   └── quimica fina
#     │   ├── engenharia de processos quimicos
#     │   ├── engenharia do petroleo
#     │   ├── engenharia quimica, de materiais e processos ambientais
#     │   └── engenharia de petroleo
#     ├── engenharia sanitaria
#     │   ├── recursos hidricos
#     │   │   ├── sedimentologia
#     │   │   ├── planejamento integrado dos recursos hidricos
#     │   │   ├── tecnologia e problemas sanitarios de irrigacao
#     │   │   ├── aguas subterraneas e pocos profundos
#     │   │   ├── controle de enchentes e de barragens
#     │   │   ├── rios urbanos
#     │   │   ├── reservatorios
#     │   │   └── gestao da agua e gestao do territorio
#     │   ├── tratamento de aguas de abastecimento e residuarias
#     │   │   ├── quimica sanitaria
#     │   │   ├── processos simplificados de tratamento de aguas
#     │   │   ├── tecnicas convencionais de tratamento de aguas
#     │   │   ├── tecnicas avancadas de tratamento de aguas
#     │   │   ├── estudos e caracterizacao de efluentes industriais
#     │   │   ├── layout de processos industriais
#     │   │   └── residuos radioativos
#     │   ├── saneamento basico
#     │   │   ├── tecnicas de abastecimento da agua
#     │   │   ├── drenagem de aguas residuarias
#     │   │   ├── drenagem urbana de aguas pluviais
#     │   │   ├── residuos solidos; domesticos e industriais
#     │   │   ├── limpeza publica
#     │   │   ├── instalacoes hidraulico-sanitarias
#     │   │   ├── gestao de residuos solidos
#     │   │   ├── tratamento e reciclagem de residuos
#     │   │   ├── solid waste management
#     │   │   ├── residuos solidos, domesticos e industriais
#     │   │   ├── residuos solidos urbanos
#     │   │   └── reutilizacao
#     │   └── saneamento ambiental
#     │       ├── ecologia aplicada a engenharia sanitaria
#     │       ├── microbiologia aplicada e engenharia sanitaria
#     │       ├── parasitologia aplicada a engenharia sanitaria
#     │       ├── qualidade do ar; das aguas e do solo
#     │       ├── controle da poluicao
#     │       ├── legislacao ambiental
#     │       ├── contaminacao por hidrocarbonetos de petroleo
#     │       ├── modelagem ambiental
#     │       ├── engenharia ambiental - poluicao atmosferica
#     │       ├── auditorias ambientais
#     │       ├── saude ambiental
#     │       ├── ambiental
#     │       ├── engenharia ambiental
#     │       ├── avaliacao ambiental in situ
#     │       ├── gestao ambiental
#     │       ├── remediacao de areas contaminadas
#     │       ├── tecnologia ambiental
#     │       ├── sequestro de co2
#     │       ├── biotecnologia ambiental e recursos naturais
#     │       └── qualidade do ar, das aguas e do solo
#     ├── engenharia de producao
#     │   ├── gerencia de producao
#     │   │   ├── planejamento de instalacoes industriais
#     │   │   ├── planejamento; projeto e controle de sistemas de producao
#     │   │   ├── higiene e seguranca do trabalho
#     │   │   │   ├── higiene ocupacional
#     │   │   │   └── engenharia de seguranca do trabalho
#     │   │   ├── suprimentos
#     │   │   │   ├── administracao de estoques
#     │   │   │   ├── logistica
#     │   │   │   ├── distribuicao fisica
#     │   │   │   ├── gestao de estoque
#     │   │   │   └── logistica empresarial
#     │   │   ├── garantia de controle de qualidade
#     │   │   │   ├── qualidade
#     │   │   │   ├── programa de qualidade
#     │   │   │   ├── gestao e qualidade
#     │   │   │   ├── controle estatistico da qualidade
#     │   │   │   ├── certificacao
#     │   │   │   ├── quality infrastructure
#     │   │   │   ├── sistema de qualidade
#     │   │   │   ├── quality improvement
#     │   │   │   ├── product certificatio
#     │   │   │   ├── programa da qualidade
#     │   │   │   └── gestao da qualidade
#     │   │   ├── qualidade e sms
#     │   │   ├── projeto e controle de sistemas de producao
#     │   │   ├── automacao de projetos e engenharia
#     │   │   ├── gestao de projetos
#     │   │   ├── planejamento, projeto e controle de sistemas de producao
#     │   │   ├── gestao de megaprojetos
#     │   │   ├── manutencao
#     │   │   ├── inpecao
#     │   │   ├── sistemas de apoio a atividade industrial
#     │   │   ├── estruturacao de projetos
#     │   │   ├── gestao da producao
#     │   │   ├── avaliacao da producao industrial
#     │   │   ├── planejamento projeto e controle de sistema de producao
#     │   │   ├── producao
#     │   │   ├── engenharia de sistema de processos
#     │   │   ├── planejamento e controle da producao
#     │   │   ├── gestao de risco em projeto
#     │   │   ├── gestao de projeto
#     │   │   ├── engenharia de sistemas
#     │   │   └── confiabilidade em ambientes competitivos
#     │   ├── pesquisa operacional
#     │   │   ├── processos estocasticos e teoria das filas
#     │   │   ├── programacao linear; nao-linear; mista e dinamica
#     │   │   │   ├── programacao linear inteira
#     │   │   │   ├── programacao linear, nao-linear, mista e dinamica
#     │   │   │   └── programacao linear nao linear mista e dinamica
#     │   │   ├── series temporais
#     │   │   │   └── analise de series temporais
#     │   │   ├── teoria dos grafos
#     │   │   │   └── teoria de grafos
#     │   │   ├── teoria dos jogos
#     │   │   ├── vehicle routing problem
#     │   │   ├── robust optimization
#     │   │   ├── decisao sob incerteza
#     │   │   ├── analise de decisao
#     │   │   ├── metodos de apoio a decisao
#     │   │   ├── modelagem de incerteza
#     │   │   ├── tomada de decisao
#     │   │   ├── apoio a decisao
#     │   │   ├── operation research
#     │   │   ├── programacao matematica
#     │   │   ├── programacao estocastica
#     │   │   ├── otimizacao estocastica
#     │   │   ├── otimizacao
#     │   │   ├── otimizacao, mecanica computacional, modelos matematicos.
#     │   │   ├── analise envoltoria de dados
#     │   │   ├── otimizacao dinamica
#     │   │   ├── decisao dinamica
#     │   │   ├── optimization
#     │   │   ├── operations research
#     │   │   ├── gestao e apoio a decisao
#     │   │   ├── otimizacao sob incerteza
#     │   │   └── pesquisa operacional e otimizacao
#     │   ├── engenharia do produto
#     │   │   ├── ergonomia
#     │   │   │   ├── ergonomia de sistemas
#     │   │   │   ├── ergonomia informacional
#     │   │   │   ├── confiabilidade humana
#     │   │   │   ├── ergonomia e usabilidade
#     │   │   │   ├── ergodesign usabilidade interface homem computador
#     │   │   │   ├── ergonomia de interfaces computacionais
#     │   │   │   └── antropometria
#     │   │   ├── metodologia de projeto do produto
#     │   │   ├── processos de trabalho
#     │   │   ├── gerencia do projeto e do produto
#     │   │   ├── desenvolvimento de produto
#     │   │   ├── ergonomia do produto
#     │   │   ├── tecnologia de processos e produtos
#     │   │   └── desenvolvimento de prototipos
#     │   ├── engenharia economica
#     │   │   ├── estudo de mercado
#     │   │   ├── localizacao industrial
#     │   │   ├── analise de custos
#     │   │   ├── economia de tecnologia
#     │   │   ├── vida economica dos equipamentos
#     │   │   ├── avaliacao de projetos
#     │   │   ├── analise e controle de risco
#     │   │   ├── avaliacao economico-financeira
#     │   │   ├── viabilidade economica
#     │   │   ├── avaliacao de projetos de energia e infraestrutura
#     │   │   ├── gerenciamento de riscos
#     │   │   ├── modelagem economico-financeira
#     │   │   ├── avaliacao de projetos industriais e tecnologias
#     │   │   ├── analise de risco
#     │   │   ├── risk analysis
#     │   │   ├── avaliacao de projeto
#     │   │   ├── analise economica e de risco
#     │   │   └── gestao de risco
#     │   ├── engenharia de producao / pesquisa operacional
#     │   └── engenharia industrial
#     ├── engenharia nuclear
#     │   ├── aplicacoes de radioisotopos
#     │   │   ├── producao de radioisotopos
#     │   │   ├── aplicacoes industriais de radioisotopos
#     │   │   └── instrumentacao para medida e controle de radiacao
#     │   ├── fusao controlada
#     │   │   ├── processos industriais da fusao controlada
#     │   │   └── problemas tecnologicos da fusao controlada
#     │   ├── combustivel nuclear
#     │   │   ├── extracao de combustivel nuclear
#     │   │   ├── conversao; enriquecimento e fabricacao de combustivel nuclear
#     │   │   ├── reprocessamento de combustivel nuclear
#     │   │   └── rejeitos de combustivel nuclear
#     │   └── tecnologia dos reatores
#     │       ├── nucleo do reator
#     │       ├── materiais nucleares e blindagem de reatores
#     │       ├── transferencia de calor em reatores
#     │       ├── geracao e integracao com sistemas eletricos em reatores
#     │       ├── instrumentacao para operacao e controle de reatores
#     │       ├── seguranca; localizacao e licenciamento de reatores
#     │       └── aspectos economicos de reatores
#     ├── engenharia de transportes
#     │   ├── planejamento de transportes
#     │   │   ├── planejamento e organizacao do sistema de transporte
#     │   │   ├── economia dos transportes
#     │   │   └── mobilidade urbana
#     │   ├── veiculos e equipamentos de controle
#     │   │   ├── vias de transporte
#     │   │   ├── veiculos de transportes
#     │   │   ├── estacao de transporte
#     │   │   ├── equipamentos auxiliares e controles
#     │   │   └── veiculos militares
#     │   ├── operacoes de transportes
#     │   │   ├── engenharia de trafego
#     │   │   │   └── seguranca de trafego
#     │   │   ├── capacidade de vias de transporte
#     │   │   └── operacao de sistemas de transporte
#     │   ├── air transportation
#     │   ├── transporte e logistica
#     │   ├── urban transportation
#     │   ├── logistica e transportes
#     │   └── engenharia de dutos
#     ├── engenharia naval e oceanica
#     │   ├── hidrodinamica de navios e sistemas oceanicos
#     │   │   ├── resistencia hidrodinamica
#     │   │   └── propulsao de navios
#     │   ├── estruturas navais e oceanicas
#     │   │   ├── analise teorica e experimental de estrutura
#     │   │   ├── dinamica estrutural naval e oceanica
#     │   │   └── sintese estrutural naval e oceanica
#     │   ├── maquinas maritimas
#     │   │   ├── analise de sistemas propulsores
#     │   │   ├── controle e automacao de sistemas propulsores
#     │   │   ├── equipamentos auxiliares do sistema propulsivo
#     │   │   └── motor de propulsao
#     │   ├── projeto de navios e de sistemas oceanicos
#     │   │   ├── projetos de navios
#     │   │   ├── projetos de sistemas oceanicos fixos e semi-fixos
#     │   │   └── projetos de embarcacoes nao-convencionais
#     │   └── tecnologia de construcao naval e de sistemas oceanicas
#     │       ├── metodos de fabricacao de navios e sistemas oceanicos
#     │       ├── soldagem de estruturas navais e oceanicos
#     │       ├── custos de construcao naval
#     │       └── normatizacao e certificacao de qualidade de navios
#     ├── engenharia aeroespacial
#     │   ├── aerodinamica
#     │   │   ├── aerodinamica de aeronaves espaciais
#     │   │   └── aerodinamica dos processos geofisicos e interplanetarios
#     │   ├── dinamica de voo
#     │   │   ├── trajetorias e orbitas
#     │   │   └── estabilidade e controle
#     │   ├── estruturas aeroespaciais
#     │   │   ├── aeroelasticicidade
#     │   │   ├── fadiga
#     │   │   │   └── fadiga de estruturas
#     │   │   └── projeto de estruturas aeroespaciais
#     │   ├── materiais e processos para engenharia aeronautica e aeroespacial
#     │   ├── propulsao aeroespacial
#     │   │   ├── combustao e escoamento com reacoes quimicas
#     │   │   ├── propulsao de foguetes
#     │   │   ├── maquinas de fluxo
#     │   │   └── motores alternativos
#     │   └── sistemas aeroespaciais
#     │       ├── avioes
#     │       ├── foguetes
#     │       ├── helicopteros
#     │       ├── hovercraft
#     │       ├── satelites e outros dispositivos aeroespaciais
#     │       ├── normatizacao e certificacao de qualidade de aeronaves e componentes
#     │       └── manutencao de sistemas aeroespaciais
#     ├── engenharia biomedica
#     ├── bioengenharia
#     │   ├── processamento de sinais biologicos
#     │   │   └── filtragem
#     │   ├── modelagem de fenomenos biologicos
#     │   ├── modelagem de sistemas biologicos
#     │   ├── bio engenharia
#     │   ├── engenharia de tecidos
#     │   └── biotecnologia
#     ├── engenharia medica
#     │   ├── biomateriais e materiais biocompativeis
#     │   ├── transdutores para aplicacoes biomedicas
#     │   ├── instrumentacao odontologica e medico-hospitalar
#     │   ├── tecnologia de proteses
#     │   ├── tecnologia assistiva
#     │   └── engenharia biomecanica
#     └── engenharia
#         ├── ensino de engenharia; engenharia no entretenimento
#         └── engenharia no entretenimento
#
# --------------------------------------------------
# Visualizando o ramo da Grande Área: 'ciencias da saude'
# --------------------------------------------------
# └── ciencias da saude
#     ├── medicina
#     │   ├── clinica medica
#     │   │   ├── angiologia
#     │   │   ├── dermatologia
#     │   │   ├── alergologia e imunologia clinica
#     │   │   ├── cancerologia
#     │   │   │   └── oncologia toracica
#     │   │   ├── hematologia
#     │   │   ├── endocrinologia
#     │   │   ├── neurologia
#     │   │   │   ├── neurologia cognitiva
#     │   │   │   ├── neurociencias
#     │   │   │   └── neurociencia
#     │   │   ├── pediatria
#     │   │   │   └── estudos sobre bebes
#     │   │   ├── doencas infecciosas e parasitarias
#     │   │   │   └── dencas infecto parasitarias
#     │   │   ├── cardiologia
#     │   │   ├── gastroenterologia
#     │   │   ├── pneumologia
#     │   │   ├── nefrologia
#     │   │   ├── reumatologia
#     │   │   ├── ginecologia e obstetricia
#     │   │   ├── fisiatria
#     │   │   ├── oftalmologia
#     │   │   └── ortopedia
#     │   ├── cirurgia
#     │   │   ├── cirurgia plastica e restauradora
#     │   │   ├── cirurgia otorrinolaringologica
#     │   │   ├── cirurgia oftalmologica
#     │   │   ├── cirurgia cardiovascular
#     │   │   ├── cirurgia toraxica
#     │   │   ├── cirurgia gastroenterologia
#     │   │   ├── cirurgia pediatrica
#     │   │   ├── neurocirurgia
#     │   │   ├── cirurgia urologica
#     │   │   ├── cirurgia proctologica
#     │   │   ├── cirurgia ortopedica
#     │   │   ├── cirurgia traumatologica
#     │   │   ├── anestesiologia
#     │   │   └── cirurgia experimental
#     │   ├── saude materno-infantil
#     │   │   ├── saude da crianca e da mulher
#     │   │   ├── medicina fetal
#     │   │   └── saude da mulher
#     │   ├── psiquiatria
#     │   │   ├── historia da psiquiatria
#     │   │   ├── instituicao psiquiatrica
#     │   │   ├── clinica psiquiatrica
#     │   │   ├── psicopatologia
#     │   │   ├── psiquiatria infantil
#     │   │   ├── psiquiatria geriatrica
#     │   │   ├── historia da saude mental
#     │   │   └── saude mental
#     │   ├── anatomia patologica e patologia clinica
#     │   │   └── fisiopatologia e diagnostico laboratorial
#     │   ├── radiologia medica
#     │   ├── medicina legal e deontologia
#     │   │   ├── tanatologia
#     │   │   └── etica medica
#     │   ├── medicina regenerativa e quimica medicinal
#     │   ├── telemedicina
#     │   └── david rubem azulay
#     ├── odontologia
#     │   ├── clinica odontologica
#     │   ├── cirurgia buco-maxilo-facial
#     │   ├── ortodontia
#     │   ├── odontopediatria
#     │   ├── periodontia
#     │   ├── endodontia
#     │   ├── radiologia odontologica
#     │   ├── odontologia social e preventiva
#     │   ├── materiais odontologicos
#     │   ├── protese dentaria
#     │   ├── protese dental
#     │   └── implantes osseointegrados
#     ├── farmacia
#     │   ├── farmacotecnia
#     │   │   └── sintese de farmacos
#     │   ├── farmacognosia
#     │   ├── analise toxicologica
#     │   │   └── avaliacao e analises toxicologicas
#     │   ├── analise e controle e medicamentos
#     │   ├── bromatologia
#     │   ├── quimica farmaceutica medicinal
#     │   ├── ciencias farmaceuticas
#     │   ├── nanomedicina
#     │   └── garantia e controle de qualidade farmaceuticos
#     ├── enfermagem
#     │   ├── enfermagem medico-cirurgica
#     │   ├── enfermagem obstetrica
#     │   ├── enfermagem pediatrica
#     │   ├── enfermagem psiquiatrica
#     │   ├── enfermagem de doencas contagiosas
#     │   └── enfermagem de saude publica
#     │       └── enfermagem em saude coletiva
#     ├── nutricao
#     │   ├── bioquimica da nutricao
#     │   ├── dietetica
#     │   ├── analise nutricional de populacao
#     │   ├── desnutricao e desenvolvimento fisiologico
#     │   ├── politica de nutricao
#     │   └── alimentacao
#     ├── saude coletiva
#     │   ├── epidemiologia
#     │   ├── saude publica
#     │   │   ├── sistema unico de saude
#     │   │   └── politicas publicas de saude
#     │   ├── medicina preventiva
#     │   ├── medicina social
#     │   ├── economia da saude
#     │   ├── historia da saude publica
#     │   ├── gerontologia
#     │   ├── gestao em saude
#     │   ├── alcool e outras drogas
#     │   ├── saude urbana
#     │   ├── avaliacao de impacto em saude
#     │   ├── ciencias sociais e humanidades em saude
#     │   └── saude da populacao negra
#     ├── fonoaudiologia
#     │   └── patologia da fala
#     ├── fisioterapia e terapia ocupacional
#     ├── educacao fisica
#     │   ├── esporte
#     │   └── futebol
#     └── saude
